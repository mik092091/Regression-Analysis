# %% [markdown]
# ## Let's Begin

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from vecstack import stacking
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.linear_model import Lasso
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from scipy.stats import norm
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score



warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Import Data and Take a look at some Features

# %%
#Importing data and looking at big picture for our dataset

data = pd.read_csv('data.csv')
print('Number of instances: ',data.shape[0])
print('Number of features: ', data.shape[1])
print()
print('Examples of some Features in the Dataset: ',list(data.columns)[1:10])
data.head(5)
# Out:
# Number of instances:  18207
# Number of features:  89
#
# Examples of some Features in the Dataset:  ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club']
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
#Dropping completely unnecessary columns before starting EDA (i.e. images of the player's country flag, club logo, etc)
data.drop(columns=['Unnamed: 0', 'Photo','Flag', 'Club Logo'],inplace=True)

# %% [markdown]
# ## Change the label (Wage) from a String to an INT

# %%
#The Wage column was originally inputted as an object (i.e. €500K) so transform them into INT (i.e 500)

data['Wage']=[i.split('€')[1].split('K')[0] for i in data['Wage']]
data['Wage'] = data['Wage'].astype('int')
data = data.rename(columns = {'Wage':'Wage (000s)'}) #changed the column name to indicate the numbers are in thousands
data
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 1       20801     Cristiano Ronaldo   33             Portugal       94
# 2      190871             Neymar Jr   26               Brazil       92
# 3      193080                De Gea   27                Spain       91
# 4      192985          K. De Bruyne   27              Belgium       91
# 5      183277             E. Hazard   27              Belgium       91
# 6      177003             L. Modrić   32              Croatia       91
# 7      176580             L. Suárez   31              Uruguay       91
# 8      155862          Sergio Ramos   32                Spain       91
# 9      200389              J. Oblak   25             Slovenia       90
# 10     188545        R. Lewandowski   29               Poland       90
# 11     182521              T. Kroos   28              Germany       90
# 12     182493              D. Godín   32              Uruguay       90
# 13     168542           David Silva   32                Spain       90
# 14     215914              N. Kanté   27               France       89
# 15     211110             P. Dybala   24            Argentina       89
# 16     202126               H. Kane   24              England       89
# 17     194765          A. Griezmann   27               France       89
# 18     192448         M. ter Stegen   26              Germany       89
# 19     192119           T. Courtois   26              Belgium       89
# 20     189511       Sergio Busquets   29                Spain       89
# 21     179813             E. Cavani   31              Uruguay       89
# 22     167495              M. Neuer   32              Germany       89
# 23     153079             S. Agüero   30            Argentina       89
# 24     138956          G. Chiellini   33                Italy       89
# 25     231747             K. Mbappé   19               France       88
# 26     209331              M. Salah   26                Egypt       88
# 27     200145              Casemiro   26               Brazil       88
# 28     198710          J. Rodríguez   26             Colombia       88
# 29     198219            L. Insigne   27                Italy       88
# ...       ...                   ...  ...                  ...      ...
# 18177  238550             R. Roache   18  Republic of Ireland       48
# 18178  243158          L. Wahlstedt   18               Sweden       48
# 18179  246243           J. Williams   17              England       48
# 18180  221669              M. Hurst   22             Scotland       48
# 18181  245734              C. Maher   17  Republic of Ireland       48
# 18182  246001               Y. Góez   18             Colombia       48
# 18183   53748         K. Pilkington   44              England       48
# 18184  241657             D. Horton   18              England       48
# 18185  243961              E. Tweed   19  Republic of Ireland       48
# 18186  240917          Zhang Yufeng   20             China PR       47
# 18187  240158             C. Ehlich   19              Germany       47
# 18188  240927            L. Collins   17                Wales       47
# 18189  240160            A. Kaltner   18              Germany       47
# 18190  245569            L. Watkins   18              England       47
# 18191  245570  J. Norville-Williams   18              England       47
# 18192  245571             S. Squire   18              England       47
# 18193  244823            N. Fuentes   18                Chile       47
# 18194  245862              J. Milli   18                Italy       47
# 18195  243582            S. Griffin   18  Republic of Ireland       47
# 18196  238477           K. Fujikawa   19                Japan       47
# 18197  246167            D. Holland   18  Republic of Ireland       47
# 18198  242844            J. Livesey   18              England       47
# 18199  244677          M. Baldisimo   18               Canada       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
# 18202  238813          J. Lundstram   19              England       47
# 18203  243165    N. Christoffersson   19               Sweden       47
# 18204  241638             B. Worman   16              England       47
# 18205  246268        D. Walker-Rice   17              England       47
# 18206  246269             G. Nugent   16              England       46
#
#        Potential                    Club    Value  Wage (000s)  Special  ...  \
# 0             94            FC Barcelona  €110.5M          565     2202  ...
# 1             94                Juventus     €77M          405     2228  ...
# 2             93     Paris Saint-Germain  €118.5M          290     2143  ...
# 3             93       Manchester United     €72M          260     1471  ...
# 4             92         Manchester City    €102M          355     2281  ...
# 5             91                 Chelsea     €93M          340     2142  ...
# 6             91             Real Madrid     €67M          420     2280  ...
# 7             91            FC Barcelona     €80M          455     2346  ...
# 8             91             Real Madrid     €51M          380     2201  ...
# 9             93         Atlético Madrid     €68M           94     1331  ...
# 10            90       FC Bayern München     €77M          205     2152  ...
# 11            90             Real Madrid   €76.5M          355     2190  ...
# 12            90         Atlético Madrid     €44M          125     1946  ...
# 13            90         Manchester City     €60M          285     2115  ...
# 14            90                 Chelsea     €63M          225     2189  ...
# 15            94                Juventus     €89M          205     2092  ...
# 16            91       Tottenham Hotspur   €83.5M          205     2165  ...
# 17            90         Atlético Madrid     €78M          145     2246  ...
# 18            92            FC Barcelona     €58M          240     1328  ...
# 19            90             Real Madrid   €53.5M          240     1311  ...
# 20            89            FC Barcelona   €51.5M          315     2065  ...
# 21            89     Paris Saint-Germain     €60M          200     2161  ...
# 22            89       FC Bayern München     €38M          130     1473  ...
# 23            89         Manchester City   €64.5M          300     2107  ...
# 24            89                Juventus     €27M          215     1841  ...
# 25            95     Paris Saint-Germain     €81M          100     2118  ...
# 26            89               Liverpool   €69.5M          255     2146  ...
# 27            90             Real Madrid   €59.5M          285     2170  ...
# 28            89       FC Bayern München   €69.5M          315     2171  ...
# 29            88                  Napoli     €62M          165     2017  ...
# ...          ...                     ...      ...          ...      ...  ...
# 18177         69               Blackpool     €70K            1     1178  ...
# 18178         65              Dalkurd FF     €50K            1      738  ...
# 18179         64        Northampton Town     €50K            1     1166  ...
# 18180         58        St. Johnstone FC     €40K            1      987  ...
# 18181         66          Bray Wanderers     €50K            1     1296  ...
# 18182         65       Atlético Nacional     €50K            1     1311  ...
# 18183         48        Cambridge United      € 0            1      774  ...
# 18184         55            Lincoln City     €40K            1     1368  ...
# 18185         59              Derry City     €50K            1     1315  ...
# 18186         64        Beijing Renhe FC     €60K            1     1389  ...
# 18187         59      SpVgg Unterhaching     €40K            1     1366  ...
# 18188         62          Newport County     €60K            1     1297  ...
# 18189         61      SpVgg Unterhaching     €60K            1     1290  ...
# 18190         67        Cambridge United     €60K            1     1285  ...
# 18191         65        Cambridge United     €50K            1     1250  ...
# 18192         64        Cambridge United     €50K            1     1325  ...
# 18193         64          Unión Española     €50K            1     1191  ...
# 18194         65                   Lecce     €50K            1      731  ...
# 18195         67            Waterford FC     €60K            1     1325  ...
# 18196         61            Júbilo Iwata     €60K            1     1333  ...
# 18197         61               Cork City     €60K            1     1362  ...
# 18198         70           Burton Albion     €60K            1      792  ...
# 18199         69  Vancouver Whitecaps FC     €70K            1     1303  ...
# 18200         62            Swindon Town     €60K            1     1203  ...
# 18201         68            Waterford FC     €60K            1     1098  ...
# 18202         65         Crewe Alexandra     €60K            1     1307  ...
# 18203         63          Trelleborgs FF     €60K            1     1098  ...
# 18204         67        Cambridge United     €60K            1     1189  ...
# 18205         66         Tranmere Rovers     €60K            1     1228  ...
# 18206         66         Tranmere Rovers     €60K            1     1321  ...
#
#       Composure  Marking  StandingTackle  SlidingTackle GKDiving GKHandling  \
# 0          96.0     33.0            28.0           26.0      6.0       11.0
# 1          95.0     28.0            31.0           23.0      7.0       11.0
# 2          94.0     27.0            24.0           33.0      9.0        9.0
# 3          68.0     15.0            21.0           13.0     90.0       85.0
# 4          88.0     68.0            58.0           51.0     15.0       13.0
# 5          91.0     34.0            27.0           22.0     11.0       12.0
# 6          84.0     60.0            76.0           73.0     13.0        9.0
# 7          85.0     62.0            45.0           38.0     27.0       25.0
# 8          82.0     87.0            92.0           91.0     11.0        8.0
# 9          70.0     27.0            12.0           18.0     86.0       92.0
# 10         86.0     34.0            42.0           19.0     15.0        6.0
# 11         85.0     72.0            79.0           69.0     10.0       11.0
# 12         82.0     90.0            89.0           89.0      6.0        8.0
# 13         93.0     59.0            53.0           29.0      6.0       15.0
# 14         85.0     90.0            91.0           85.0     15.0       12.0
# 15         84.0     23.0            20.0           20.0      5.0        4.0
# 16         89.0     56.0            36.0           38.0      8.0       10.0
# 17         87.0     59.0            47.0           48.0     14.0        8.0
# 18         69.0     25.0            13.0           10.0     87.0       85.0
# 19         66.0     20.0            18.0           16.0     85.0       91.0
# 20         90.0     90.0            86.0           80.0      5.0        8.0
# 21         82.0     52.0            45.0           39.0     12.0        5.0
# 22         70.0     17.0            10.0           11.0     90.0       86.0
# 23         90.0     30.0            20.0           12.0     13.0       15.0
# 24         84.0     93.0            93.0           90.0      3.0        3.0
# 25         86.0     34.0            34.0           32.0     13.0        5.0
# 26         91.0     38.0            43.0           41.0     14.0       14.0
# 27         84.0     88.0            90.0           87.0     13.0       14.0
# 28         87.0     52.0            41.0           44.0     15.0       15.0
# 29         83.0     51.0            24.0           22.0      8.0        4.0
# ...         ...      ...             ...            ...      ...        ...
# 18177      49.0     18.0            16.0           11.0      6.0        9.0
# 18178      28.0     16.0            11.0           10.0     47.0       46.0
# 18179      37.0     42.0            51.0           49.0     14.0       11.0
# 18180      28.0     12.0            15.0           16.0     45.0       49.0
# 18181      38.0     43.0            49.0           45.0      8.0       10.0
# 18182      38.0     44.0            42.0           46.0      9.0       15.0
# 18183      56.0     15.0            15.0           13.0     45.0       48.0
# 18184      42.0     47.0            49.0           53.0     12.0        5.0
# 18185      43.0     39.0            39.0           48.0      6.0       11.0
# 18186      39.0     53.0            41.0           51.0     15.0        7.0
# 18187      47.0     40.0            42.0           42.0     13.0       12.0
# 18188      46.0     33.0            38.0           41.0      5.0       12.0
# 18189      37.0     28.0            15.0           22.0     15.0        5.0
# 18190      46.0     35.0            44.0           47.0     13.0        7.0
# 18191      36.0     45.0            42.0           46.0     15.0       13.0
# 18192      38.0     41.0            41.0           44.0     11.0       11.0
# 18193      32.0     41.0            48.0           48.0      6.0       10.0
# 18194      23.0      6.0            10.0           11.0     52.0       52.0
# 18195      41.0     44.0            37.0           48.0     13.0       14.0
# 18196      35.0     41.0            44.0           54.0     10.0       12.0
# 18197      52.0     41.0            47.0           38.0     13.0        6.0
# 18198      34.0     15.0            11.0           13.0     46.0       52.0
# 18199      40.0     48.0            49.0           49.0      7.0        7.0
# 18200      50.0     15.0            17.0           14.0     11.0       15.0
# 18201      43.0     44.0            47.0           53.0      9.0       10.0
# 18202      45.0     40.0            48.0           47.0     10.0       13.0
# 18203      42.0     22.0            15.0           19.0     10.0        9.0
# 18204      41.0     32.0            13.0           11.0      6.0        5.0
# 18205      46.0     20.0            25.0           27.0     14.0        6.0
# 18206      43.0     40.0            43.0           50.0     10.0       15.0
#
#       GKKicking GKPositioning  GKReflexes Release Clause
# 0          15.0          14.0         8.0        €226.5M
# 1          15.0          14.0        11.0        €127.1M
# 2          15.0          15.0        11.0        €228.1M
# 3          87.0          88.0        94.0        €138.6M
# 4           5.0          10.0        13.0        €196.4M
# 5           6.0           8.0         8.0        €172.1M
# 6           7.0          14.0         9.0        €137.4M
# 7          31.0          33.0        37.0          €164M
# 8           9.0           7.0        11.0        €104.6M
# 9          78.0          88.0        89.0        €144.5M
# 10         12.0           8.0        10.0        €127.1M
# 11         13.0           7.0        10.0        €156.8M
# 12         15.0           5.0        15.0         €90.2M
# 13          7.0           6.0        12.0          €111M
# 14         10.0           7.0        10.0        €121.3M
# 15          4.0           5.0         8.0        €153.5M
# 16         11.0          14.0        11.0        €160.7M
# 17         14.0          13.0        14.0        €165.8M
# 18         88.0          85.0        90.0        €123.3M
# 19         72.0          86.0        88.0        €113.7M
# 20         13.0           9.0        13.0        €105.6M
# 21         13.0          13.0        10.0          €111M
# 22         91.0          87.0        87.0         €62.7M
# 23          6.0          11.0        14.0        €119.3M
# 24          2.0           4.0         3.0         €44.6M
# 25          7.0          11.0         6.0        €166.1M
# 26          9.0          11.0        14.0        €137.3M
# 27         16.0          12.0        12.0        €126.4M
# 28         15.0           5.0        14.0            NaN
# 29         14.0           9.0        10.0        €105.4M
# ...         ...           ...         ...            ...
# 18177      11.0           7.0        12.0          €193K
# 18178      50.0          45.0        51.0           €94K
# 18179       7.0          11.0         8.0          €119K
# 18180      50.0          50.0        45.0           €78K
# 18181      12.0           9.0        10.0          €109K
# 18182      15.0           8.0         6.0          €101K
# 18183      44.0          49.0        46.0            NaN
# 18184      12.0          14.0        15.0           €78K
# 18185       9.0           5.0         8.0           €88K
# 18186      14.0           6.0         8.0          €167K
# 18187      11.0          15.0        12.0           €66K
# 18188       8.0          13.0        10.0          €143K
# 18189      14.0          12.0         8.0          €125K
# 18190      14.0          10.0         8.0          €165K
# 18191       6.0          14.0        12.0          €119K
# 18192       8.0          12.0        13.0          €119K
# 18193       6.0          12.0        11.0           €99K
# 18194      52.0          40.0        44.0          €109K
# 18195      12.0           7.0        13.0          €153K
# 18196       6.0          11.0         8.0          €113K
# 18197       9.0          10.0        15.0           €88K
# 18198      58.0          42.0        48.0          €165K
# 18199       9.0          14.0        15.0          €175K
# 18200      12.0          12.0        11.0          €143K
# 18201       9.0          11.0        13.0          €153K
# 18202       7.0           8.0         9.0          €143K
# 18203       9.0           5.0        12.0          €113K
# 18204      10.0           6.0        13.0          €165K
# 18205      14.0           8.0         9.0          €143K
# 18206       9.0          12.0         9.0          €165K
#
# [18207 rows x 85 columns]

# %%
# see how many numerical and categorical variables we have currently
categorical = len(data.dtypes[data.dtypes =='object'])
numerical = len(data.dtypes[data.dtypes !='object'])
print('Number of Categorical Variables: %d'%categorical)
print('Number of Numerical Variables: {}'.format(numerical))
# Out:
# Number of Categorical Variables: 41
# Number of Numerical Variables: 44

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Basic stats of player's Wages

# %%
# Let's take a look at the wages as a whole. 
print(data['Wage (000s)'].describe())
print()
# the mean only stands at 9.73 despite having players like Messi earn over 560. This indicates a vast majority of players
# that are less well-known earn much lower wages. Let's see how how many players are earning some of the lowest wages. 


print(data.groupby('Wage (000s)')['Wage (000s)'].count().head(6))

# you can see here that around ~11,000 players earn less than €5 (in thousands) which is what's bringing down our mean. 


sns.distplot(data['Wage (000s)']);

# you can see this is severly positively skewed. We will apply a log transformation later to fix this issue
# This is mainly due to the the superstars that earn so much more comparatively than their lesser-known peers
# Out:
# count    18207.000000
# mean         9.731312
# std         21.999290
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          9.000000
# max        565.000000
# Name: Wage (000s), dtype: float64
#
# Wage (000s)
# 0     241
# 1    4900
# 2    2827
# 3    1857
# 4    1255
# 5     869
# Name: Wage (000s), dtype: int64

# %% [markdown]
# ## Initial Correlation Matrix (Heatmap)

# %%
corrmat = data.corr()
plt.subplots(figsize=(12,12))
sns.heatmap(corrmat, vmax=0.9, square=True);

#Right off the bat, you notice a couple of big white squares on the bottom right of the heatmap 
#which indicate high correlation (multicollinearity issues)

# For example, you can see the GK attributes (reflexes, diving, positioning) are all highly correlated meaning if you're a GK, you
# will likely score high on all these features relative to players in other positions. 

#you can also see 'Marking' has high correlation with the Tackles (a trait associated mostly for defenders)
# if you're a defender, you will most likely have a higher score in these features than your attacking forward counterparts

#You can also see that the Jersey Number has a terrible correlation with almost all features. That's because Jersey Numbers
# are not representative numerically but rather as a nominal categorical value

# %% [markdown]
# ## 10 highest correlation

# %%
newcorr = corrmat['Wage (000s)'].sort_values(ascending=False)[:10].index

sns.heatmap(data[newcorr].corr(),annot=True, square= True,);

# #Just from an initial standpoint, we see that international reputation is the biggest indicator of a player's wage.

# %% [markdown]
# ## Wage against a player's Age (in their 20s)

# %%
# Lets take a look at a couple variables that I personally think contributes to higher wage. 
plt.subplots(figsize=(12,6))
newage = data[(data['Age']>20) & (data['Age']<30)]

plt.ylim(0, 100)

sns.boxplot(newage['Age'],newage['Wage (000s)'])

# we're only looking at wages for the ages between 20 and 30. You can see on average, the older you get, the higher 
# your wage will be. This makese intuitive sense. The more experience you can acquire playing the game, the higher your 
# value should be (hence higher income). I've excluded the outliers because it's not a good representation of the rest 
# of the players due to superstar wages like Messi and Ronaldo.

# %% [markdown]
# ## Wage against Overall Rating (above 80 out of 100)

# %%
overall_data = data[data['Overall']>80]
plt.scatter(overall_data['Overall'],overall_data['Wage (000s)'])

#get the average line
z = np.polyfit(overall_data['Overall'],overall_data['Wage (000s)'] ,1)
p = np.poly1d(z)

plt.plot(overall_data['Overall'],p(overall_data['Overall']),"r--");
plt.xlabel('Overall Player Rating');
plt.ylabel('Wage (000s)');


# Overall score of a player also has a positive correlation to the wages they earn. 

#There are other factors but i'd like to get through data preprocessing before we talk about more.

# %% [markdown]
# ## Preprocessing Data (missing data, multicolinearity, categorical transformation, etc)

# %%
# Get rid of multicollinearity issues
# GKDiving, GKHandling, GKPositioning, GKReflexes are all indicators of whether a player is a GK or not. 
#Therefore we will delete all columns and only keep GKReflexes (which I believe is the best indicator of a quality GK)
columns = ['GKDiving','GKHandling','GKKicking','GKPositioning']
data.drop(columns =columns, axis = 1, inplace=True)

# %%
# Another Multicollinearity issues regarding 'Marking','Sliding Tackle','Standing Tackle'. 
# We will take the average of the 3 and rename the column 'Defense Points' - and drop the original three
data['Defense Points']=data[['Marking','StandingTackle','SlidingTackle']].mean(axis = 1).apply(lambda x: round(x,2))
columns = ['Marking','SlidingTackle','StandingTackle']
data.drop(columns = columns, axis = 1, inplace=True)

# %% [markdown]
# ## we can drop the following for these reasons:
#     Id: arbitrary ID assigned to each player
#
#     Special: was given no explanation on what these numbers mean
#
#     Work Rate: was given no explanation
#
#     Body Type: Don't think a 'lean body' and a 'normal body' was a big differentiator when it comes to someone's wage
#
#     Real Face: was given no explanation
#
#     Joined: Players move teams all the time. Joined date on the player's current team will not be a big indicator (Take Cristiano Ronaldo for example, he is the world's best but joined Juventus in 2018 vs. Messi joining his life-long club Barcelona in 2004)
#
#     Loaned From: Irrelevant
#
#     Contract Valid Until: not a big factor that contributes to determining wage
#
#     Release Clause: some relevance to a player's value so wanted to avoid any multicollinearity issues

# %%
# we can drop the followID and Special because they are purely
delete_col = ['ID','Special','Work Rate', 'Body Type', 'Real Face','Joined', 'Loaned From', 'Contract Valid Until',
             'Release Clause']
data.drop(columns = delete_col, axis = 1, inplace=True)

# %% [markdown]
# ## MISSING DATA

# %%
missing =pd.DataFrame(data.isnull().sum(), columns = ['Missing Data'])
missing = missing.sort_values('Missing Data',ascending=False)
print(missing)
#You can see consistencies in 2085 of the players missing the same information (i.e RDM, CF, RW, etc)
#Let's take a look and delete since we can't really impute the data here.. (we can't make up their positional skills) 

missing_1 = data[data['RDM'].isnull()] # pulling dataframe with only the 2085 missing data
print(missing_1['Position']) #Looking at the dataframe, I noticed all the players were GoalKeepers. 

# That makes sense. There wouldn't be any need to score Goalkeepers on their skills as a "RDM" or "Right Defensive Mid"
#For this case, we will go ahead and delete all 2085 instances and move forward with our model without any goalkeepers information 

missing_gk = missing_1.index
data.drop(missing_gk,axis = 0,inplace=True)
# Out:
#                           Missing Data
# RDM                               2085
# CF                                2085
# RW                                2085
# CAM                               2085
# RAM                               2085
# LM                                2085
# LCM                               2085
# CM                                2085
# RCM                               2085
# RM                                2085
# LWB                               2085
# LDM                               2085
# CDM                               2085
# RWB                               2085
# LB                                2085
# LCB                               2085
# CB                                2085
# RCB                               2085
# RB                                2085
# RF                                2085
# LAM                               2085
# LF                                2085
# RS                                2085
# LW                                2085
# ST                                2085
# LS                                2085
# Club                               241
# Position                            60
# Jersey Number                       60
# SprintSpeed                         48
# ...                                ...
# Positioning                         48
# Interceptions                       48
# Aggression                          48
# LongShots                           48
# Strength                            48
# Stamina                             48
# Jumping                             48
# FKAccuracy                          48
# LongPassing                         48
# Defense Points                      48
# Curve                               48
# Weight                              48
# Preferred Foot                      48
# International Reputation            48
# Weak Foot                           48
# Dribbling                           48
# Height                              48
# Skill Moves                         48
# Crossing                            48
# Finishing                           48
# HeadingAccuracy                     48
# ShortPassing                        48
# Volleys                             48
# Age                                  0
# Wage (000s)                          0
# Value                                0
# Potential                            0
# Overall                              0
# Nationality                          0
# Name                                 0
#
# [70 rows x 1 columns]
# 3        GK
# 9        GK
# 18       GK
# 19       GK
# 22       GK
# 37       GK
# 40       GK
# 41       GK
# 46       GK
# 57       GK
# 81       GK
# 92       GK
# 126      GK
# 128      GK
# 131      GK
# 133      GK
# 141      GK
# 147      GK
# 149      GK
# 177      GK
# 180      GK
# 189      GK
# 196      GK
# 197      GK
# 201      GK
# 210      GK
# 212      GK
# 213      GK
# 214      GK
# 218      GK
#          ..
# 18068    GK
# 18073    GK
# 18074    GK
# 18093    GK
# 18096    GK
# 18097    GK
# 18101    GK
# 18103    GK
# 18104    GK
# 18106    GK
# 18108    GK
# 18112    GK
# 18113    GK
# 18117    GK
# 18122    GK
# 18127    GK
# 18128    GK
# 18136    GK
# 18143    GK
# 18145    GK
# 18147    GK
# 18149    GK
# 18158    GK
# 18160    GK
# 18172    GK
# 18178    GK
# 18180    GK
# 18183    GK
# 18194    GK
# 18198    GK
# Name: Position, Length: 2085, dtype: object

# %%
# Deleting those 2085 goalkeepers data seems to have fixed all but one of our null value issues. 
print(data.isnull().sum().sort_values(ascending=False).head(5))

#you can see now there is only one category left with null values. It is 'Club' and we will go ahead and replace them 
#with 'None'

data['Club']=data['Club'].fillna(value='None')

data.columns[data.isnull().sum() > 0]
#Now we have no Null Values.
# Out:
# Club              196
# Defense Points      0
# CAM                 0
# LW                  0
# LF                  0
# dtype: int64
# Index([], dtype='object')

# %% [markdown]
# ## One Hot Encode Positions (ST, LW, CAM, etc)

# %%
ohe = OneHotEncoder(sparse = False)
df = pd.DataFrame(ohe.fit_transform(data[['Position']]), columns = ohe.get_feature_names(), index = data.index)
df.drop(columns = 'x0_CAM',inplace=True )
data = pd.concat([data,df],axis=1)
data.drop(columns = ['Position'],axis=1,inplace=True)
#drop one of the OneHotEncoded columns and merge it back to the original DataFrame
#also drop the original 'Position' column

# %% [markdown]
# ### Change height to cm, change weight to numeric only, take out the plus sign in all position rating (i.e. ST for messi is 88+2 --> change this to just 88)

# %%
# Weight to numeric
data['Weight']=data['Weight'].apply(lambda x: x[:-3])
data['Weight'].head(5)
# Out:
# 0    159
# 1    183
# 2    150
# 4    154
# 5    163
# Name: Weight, dtype: object

# %%
# Change height to cm
def ChangeHeight(x):
    feet=int(x.split("\'")[0])
    inches =int(x.split("\'")[1])
    return (feet*30.48) + (inches*2.54)

data['Height'] = data['Height'].apply(ChangeHeight)
data['Height'].head(5)
# Out:
# 0    170.18
# 1    187.96
# 2    175.26
# 4    180.34
# 5    172.72
# Name: Height, dtype: float64

# %%
#Take out the plus sign in each of the position ratings
cols = ['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB',
        'LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB']

for col in cols:
    data[col] = data[col].apply(lambda x: x.split('+')[0])

# %%
# set the DataFrame index to the player's names
data = data.set_index('Name')

# %% [markdown]
# ## Delete 4 more variables that aren't indicative of Wage (Nationality, Club, Preferred Foot, Value)
# #### before that though, I'd like to check a couple things

# %%
club = data.groupby('Club')['Wage (000s)'].mean().sort_values(ascending=False)[:10] #Top 10 clubs with highest avg Wage

jersey = pd.Series(data.groupby('Jersey Number').size().sort_values(ascending=False).nlargest(10).index).astype('str')
jersey_series = data.groupby('Jersey Number')['Wage (000s)'].mean()
jersey_final =jersey_series[jersey_series.index.isin(jersey)].reset_index() #Wage by the Top 10 most worn Jersey Number
jersey_final['Jersey Number'] = jersey_final['Jersey Number'].astype('str').apply(lambda x:x.split('.')[0])


fig, ax = plt.subplots(1,2,figsize =(18,8))
ax[0].set_title('Top 10 Clubs with highest Wage')
plt.sca(ax[0])
plt.xticks(rotation=90)
ax[0].bar(club.index,club.values,color='gggbbbrrrr')

plt.sca(ax[1])
ax[1].set_title('Wages for Top 10 most worn Jersey Number')
plt.xticks(rotation=90)
plt.tick_params(labelsize=14)
ax[1].bar(jersey_final['Jersey Number'],jersey_final['Wage (000s)'],color = 'bbbbgbggbb')


# As you can see, if you play for any of the top 10 teams listed on the left graph, you're most likely goign to get paid out
# Also, historically speaking, Jersey #10 is worn by the best player on the team. The chart on the right shows that 
#the wages paid to a Number 10 is on average higher than any other numbers worn. Number 7 and 9 are highly sought after too
# Out:
# <BarContainer object of 10 artists>

# %%
# delete the 4 variables: Nationality, Club, Preferred Foot, Value
data.drop(columns = ['Nationality', 'Club','Preferred Foot','Value'],axis = 1, inplace=True)

# %% [markdown]
# ## Log Transformation of Wage

# %%
data['Wage (000s)'] = np.log(data['Wage (000s)']+1) #we added 1 
data['Wage (000s)'].head()
# Out:
# Name
# L. Messi             6.338594
# Cristiano Ronaldo    6.006353
# Neymar Jr            5.673323
# K. De Bruyne         5.874931
# E. Hazard            5.831882
# Name: Wage (000s), dtype: float64

# %%
#Let's try making the distribution plot again for the Wage

sns.distplot(data['Wage (000s)'],fit= norm)
# not  but better than the first distplot we made earlier

# %% [markdown]
# ## Split into Train Test

# %%
X = data.drop('Wage (000s)',axis=1)
y = data['Wage (000s)']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, test_size = 0.25)

# %% [markdown]
# ## Setup CV (cross-validation)

# %%
n = 6
kf = KFold(n_splits = n, shuffle=True, random_state = 1)

def CVS(model):
    results = np.sqrt(-cross_val_score(model, Xtrain, ytrain, cv = kf, scoring='neg_mean_squared_error'))
    return results, results.mean()

# %%
rf = RandomForestRegressor(max_features=None,
                          oob_score=True,
                          random_state=42)
rf_params= {'n_estimators':[100,200,300,400,500],
           'max_depth':[5,10,15,20],
           'min_samples_split':[2,3,4,5],
           'min_samples_leaf':[1,2,3]}


clf_rf = RandomizedSearchCV(rf,rf_params, n_iter=10)

model_1 = clf_rf.fit(Xtrain,ytrain)

# %%
model_1.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features=None, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=5, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=True,
#                       random_state=42, verbose=0, warm_start=False)

# %%
rf_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=20, max_features=None, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=5, min_weight_fraction_leaf=0.0,
                      n_estimators=200, n_jobs=None, oob_score=True,
                      random_state=42, verbose=0, warm_start=False)
CVS(rf_2)
# Out:
# (array([0.56265662, 0.56995619, 0.54813916, 0.57320609, 0.56838934,
#         0.55508936]), 0.562906126884494)

# %%
gbr = GradientBoostingRegressor(loss='huber',
                                max_features='auto',
                                learning_rate= 0.01,
                                random_state=42,
                                n_estimators=5000,
                                min_samples_leaf=1,
                                min_samples_split= 3,
                                max_depth=5) 

CVS(gbr)
# Out:
# (array([0.56397027, 0.57055509, 0.54582696, 0.57778195, 0.56945302,
#         0.55256379]), 0.5633585151780341)

# %%
model_2 = gbr.fit(Xtrain,ytrain)

# %%
lr = make_pipeline(RobustScaler(), Lasso(alpha =0.0005))

# %%
CVS(lr)
# Out:
# (array([0.60562769, 0.61079233, 0.59626874, 0.61432169, 0.60655343,
#         0.59392906]), 0.6045821575259804)

# %%
model_3 = lr.fit(Xtrain,ytrain)

# %%
ypred = model_1.predict(Xtest)
print(np.sqrt(mean_squared_error(ytest,ypred)))

ypred1= gbr.predict(Xtest)
print(np.sqrt(mean_squared_error(ytest,ypred1)))

ypred2= lr.predict(Xtest)
print(np.sqrt(mean_squared_error(ytest,ypred2)))
# Out:
# 0.5433926845727305
# 0.5438634101364126
# 0.586231001055801

# %% [markdown]
# ## STACKING BOTH MODELS

# %%
pip install vecstack

# %%
models = [RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=20, max_features=None, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=5, min_weight_fraction_leaf=0.0,
                      n_estimators=200, n_jobs=None, oob_score=True,
                      random_state=42, verbose=0, warm_start=False),

GradientBoostingRegressor(loss='huber',
                                max_features='auto',
                                learning_rate= 0.01,
                                random_state=42,
                                n_estimators=5000,
                                min_samples_leaf=1,
                                min_samples_split= 3,
                                max_depth=5),
Lasso(alpha =0.0005)

]

# %%
S_train, S_test = stacking(models,                   
                           Xtrain, ytrain, Xtest,   
                           regression=True,      
                           mode='oof_pred_bag', 
                           needs_proba=False,
                           save_dir=None, 
                           metric=mean_squared_error,
                           n_folds=4, 
                           stratified=False,
                           shuffle=True,  
                           random_state=0,    
                           verbose=2)
# Out:
# task:         [regression]
# metric:       [mean_squared_error]
# mode:         [oof_pred_bag]
# n_models:     [3]
#
# model  0:     [RandomForestRegressor]
#     fold  0:  [0.31871585]
#     fold  1:  [0.30202504]
#     fold  2:  [0.32837049]
#     fold  3:  [0.33095402]
#     ----
#     MEAN:     [0.32001635] + [0.01134463]
#     FULL:     [0.32001545]
#
# model  1:     [GradientBoostingRegressor]
#     fold  0:  [0.31732557]
#     fold  1:  [0.29912273]
#     fold  2:  [0.32506543]
#     fold  3:  [0.33082159]
#     ----
#     MEAN:     [0.31808383] + [0.01194876]
#     FULL:     [0.31808278]
#
# model  2:     [Lasso]
#     fold  0:  [0.36825077]
#     fold  1:  [0.34943028]
#     fold  2:  [0.36950485]
#     fold  3:  [0.37860520]
#     ----
#     MEAN:     [0.36644778] + [0.01060654]
#     FULL:     [0.36644677]

# %%
model = GradientBoostingRegressor(loss='huber',
                                max_features='auto',
                                learning_rate= 0.01,
                                random_state=42,
                                n_estimators=5000,
                                min_samples_leaf=1,
                                min_samples_split= 3,
                                max_depth=5) 

model = model.fit(S_train,ytrain)
ypred_final = model.predict(S_test)
print(np.sqrt(mean_squared_error(ytest,ypred_final)))
# Out:
# 0.5539285663751813

# %%
yprediction = pd.Series(ypred_final, index = Xtest.index)

# %%
finals = pd.concat([yprediction,ytest],keys = ['pred','actual'],axis=1)
# finals.sample(frac=0.01)
# Out:
#                        pred    actual
# Name
# A. Ogbonna         3.524524  4.189655
# A. Al Dhafeeri     0.843368  1.609438
# R. Insigne         2.344378  3.465736
# H. Hermannsson     2.342068  2.397895
# M. Gobbi           2.360033  2.833213
# Zhou Dadi          1.006401  1.098612
# B. Al Mutairi      0.996341  1.386294
# L. Henderson       1.832767  1.098612
# Dyego Sousa        3.447466  2.995732
# A. Kokoszka        0.966325  0.693147
# Jorge Molina       2.550641  3.044522
# N. Fiedler         0.825356  0.693147
# Gabriel            1.449846  1.945910
# Marcos Paneira     2.528823  2.484907
# L. Bonucci         5.011289  5.081404
# B. García          1.700315  1.609438
# Q. Promes          4.052673  3.367296
# Kel Perinho        2.379440  2.708050
# B. Martins Indi    2.820163  3.555348
# H. Arter           2.977276  4.025352
# K. Engel           1.356720  1.098612
# N. Omladič         2.170219  2.079442
# M. Yumlu           2.092411  2.484907
# E. Apeh            1.555781  1.791759
# J. Pohjanpalo      2.507436  3.583519
# A. Robertson       3.893198  4.595120
# S. Gronsveld       1.032362  0.693147
# S. Amrabat         2.797428  2.639057
# P. Gibaud          1.625489  1.386294
# L. Ritson          0.971425  1.098612
# ...                     ...       ...
# J. Sánchez         2.437560  3.135494
# L. Colville        0.836269  0.693147
# C. Stockton        0.947087  1.098612
# N. Raskin          1.045081  1.098612
# E. Marcondes       1.710722  2.708050
# Han Seok Jong      1.243447  1.098612
# F. Mussa           1.046692  1.098612
# W. Ben Yedder      4.118458  3.367296
# D. Arias           0.731310  0.693147
# R. Palacio         3.343284  3.332205
# Y. Osorio          2.917603  2.397895
# M. Harris          0.733508  1.386294
# K. Vogt            3.825755  3.761200
# Fernando Costanza  0.742946  1.098612
# F. Lobos           0.947999  0.693147
# Y. Suzuki          0.720688  0.693147
# C. Ikonomidis      2.039900  1.386294
# G. Madine          2.113479  3.135494
# S. Parlati         0.855794  0.693147
# K. De Bruyne       5.905496  5.874931
# N. Zaniolo         1.673376  2.079442
# C. Tovar           0.747827  0.693147
# S. Adrian          1.009803  0.693147
# L. Gassama         1.696460  2.302585
# R. Improta         2.313813  1.386294
# M. Maâzou          1.362485  1.609438
# F. Platte          2.786366  2.484907
# Philipe Sampaio    1.809889  1.945910
# S. Reese           1.010014  1.609438
# J. Michel          2.120305  1.945910
#
# [4031 rows x 2 columns]

# %%
import math
finals_copy = finals.copy()
for i in finals_copy.columns:
    finals_copy[i]= finals_copy[i].apply(lambda x: math.exp(x))

# %%
plt.scatter(finals_copy['pred'],finals_copy['actual'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(0, 0.5, 'Actual')
